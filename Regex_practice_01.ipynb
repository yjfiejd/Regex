# %%
import pandas as pd
import re

# %%
pd.set_option('max_colwidth', 500)

# %%
# #子函数判断：True or False
# def Match_true_false_None(match):
#     if match is not None :
#         result = re.search(r'[无|未|否|不]', match.group(0), re.I)
#         if result is not None:
#             return False
#         else:
#             return True
#     else:
#         return None

# %%
#针对体格检查的表格，设置找到比如（阳性or阴性）为True，没有找到则为None
def Match_true_false(match_result):
    if match_result is not None:
        return True
    else:
        return None

# %%
#1）左侧直腿抬高阳性
def zuotuitaigaoyang(text):
#     rule = r'(左侧直腿|双下肢|直腿抬高试验左侧|下肢|直腿)[^.,，。：；]*(引出|阳|\+|阳性)'
    rule = r'(左侧直腿|左腿|双下肢|左下肢直腿|双肢)[^.,，。：；]*(引出|阳|\+|阳性)'
    match = re.search(rule, text, re.I)
    match_result = Match_true_false(match)
    return match_result

# %%
zuotuitaigaoyang('体温：37.0℃；\n脉搏：70次/分钟；\n呼吸频率：18次/分钟；\n收缩压：145mmHg；\n舒张压：70mmHg；\n一般情况：发育正常，营养状况良好，神志清，对答切题，查体配合\n皮肤黏膜：无色素沉着、皮肤光滑及弹性尚可，无皮疹，无出血、无皮下结节。\n淋巴结：全身浅表淋巴节无肿大，触之无压痛。\n头部及其器官：头颅  形态对称，无包块、无压痛   头皮 头发浓密有光泽  \n眼睛  眼睑无水肿，双侧视力可   巩膜  无黄染   瞳孔  等大等圆，对光反射存在\n耳  听力可，无流脓及乳突压痛   鼻  通畅   口咽  无充血、红肿。\n颈部：颈软且无抵抗，双侧对称。甲状腺无肿大，气管居中\n胸部：胸廓对称，腹式呼吸为主，节律规整。\n心脏：心脏  心率70次/分，律齐，各听诊区未闻及明显病理性杂音,无心包摩擦音。\n肺脏：肺部  两肺呼吸音正常，未闻及干、湿啰音。\n血管：无色素沉着、皮肤光滑及弹性尚可，无皮疹，无出血、无皮下结节。\n腹部：腹对称，腹壁静脉无怒张无隆起，腹壁柔软,无压痛、反跳痛、振水音及液波震颤，肝脾肋下未及，移动性浊音（-），肠鸣音正常，无血管杂音。\n肛门直肠,外生殖器：未查\n脊柱四肢：见专科检查\n神经系统：腹壁反射等生理反射正常，Babinski征等病理反射未引出。\n专科检查：脊柱生理弯曲存在，腰椎棘突旁无明显压痛，无明显叩击痛。右下肢直腿抬高试验（±），加强试验（±），左下肢直腿抬高试验+性，加强试验阴性。双膝反射减弱，双下肢跟腱反射减弱。双下肢感觉对称正常，右足底感觉减退，双下肢髂腰肌肌力左侧Ⅳ级，右侧Ⅳ级；双侧股四头肌肌力左侧Ⅴ级，右侧Ⅴ级。胫骨前肌肌力左侧Ⅳ级，右侧Ⅳ级；拇背伸肌肌力左侧Ⅴ级，右侧Ⅴ级。腓肠肌肌力左侧Ⅴ级，右侧Ⅴ级。双下肢足背动脉可扪及。病理征未引出。\n')
# Out:
# True

# %%
a3='双下肢直腿抬高试验+性双膝反'
zuotuitaigaoyang(a3)
# Out:
# True

# %%
# 2）右侧直腿抬高阳性
def youtuitaigaoyang(text):
    rule = r'(右侧直腿|右腿|双下肢|右下肢直腿|双肢)[^.,，。：；]*(引出|阳|\+|阳性)'
    match = re.search(rule, text, re.I)
    match_result = Match_true_false(match)
    return match_result

# %%
a2 = '无隆起，腹壁柔软,无压痛、反跳痛、振水音及液波震颤，肝脾肋下未及，移动性浊音（-），肠鸣音正常，无血管杂音。\n肛门直肠,外生殖器：未查\n脊柱四肢：见专科检查\n神经系统：腹壁反射等生理反射正常，Babinski征等病理反射未引出。\n专科检查：脊柱生理弯曲存在，腰椎棘突旁无明显压痛，无明显叩击痛。双下肢足背足底感觉异常。双下肢直腿抬高试验性，加强试验性。双膝反射减弱，双下肢跟腱反射减弱。双下肢感觉对称，双下肢髂腰肌肌力左侧Ⅴ级，右'
youtuitaigaoyang(a2)

# %%
#3）左侧直腿抬高阴性
def zuotuitaigaoyin(text):
    rule = r'(左侧直腿|左腿|双下肢|左下肢直腿|双肢|左足)[^.,，。：；]*(未引出|阴|\-|阴性)'
    match = re.search(rule, text, re.I)
    match_result = Match_true_false(match)
    return match_result

# %%
zuotuitaigaoyin('查：脊柱生理弯曲存在，腰椎棘突旁无明显压痛，无明显叩击痛，左下肢直腿抬高试验阴性')
# Out:
# True

# %%
#4）右侧直腿抬高阴性
def youtuitaigaoyin(text):
    rule = r'(右侧直腿|右腿|双下肢|双肢|右足|右下肢直腿|，右侧)[^.,，。：；]*(未引出|阴|\-|阴性)'
    match = re.search(rule, text, re.I)
    match_result = Match_true_false(match)
    return match_result

# %%
youtuitaigaoyin('体温：36.9℃；\n脉搏：78次/分钟；\n呼吸频率：18次/分钟；\n收缩压：138mmHg；\n舒张压：89mmHg；\n一般情况：发育正常，营养状况良好，神志清，对答切题，查体配合\n皮肤黏膜：无色素沉着、皮肤光滑及弹性尚可，无皮疹，无出血、无皮下结节。\n淋巴结：全身浅表淋巴节无肿大，触之无压痛。\n头部及其器官：头颅  形态对称，无包块、无压痛   头皮 头发浓密有光泽  \n眼睛  眼睑无水肿，双侧视力可   巩膜  无黄染   瞳孔  等大等圆，对光反射存在\n耳  听力可，无流脓及乳突压痛   鼻  通畅   口咽  无充血、红肿。\n颈部：颈软且无抵抗，双侧对称。甲状腺无肿大，气管居中\n胸部：胸廓对称，腹式呼吸为主，节律规整。\n心脏：心脏  心率78次/分，律齐，各听诊区未闻及明显病理性杂音,无心包摩擦音。\n肺脏：肺部  两肺呼吸音正常，未闻及干、湿啰音。\n血管：无色素沉着、皮肤光滑及弹性尚可，无皮疹，无出血、无皮下结节。\n腹部：腹对称，腹壁静脉无怒张无隆起，腹壁柔软,无压痛、反跳痛、振水音及液波震颤，肝脾肋下未及，移动性浊音（-），肠鸣音正常，无血管杂音。\n肛门直肠,外生殖器：未查\n脊柱四肢：见专科检查\n神经系统：见专科检查\n专科检查：脊柱生理弯曲存在，腰椎棘突旁压痛、叩击痛阳性，直腿抬高试验左侧阳性，右侧阴性，双膝反射、跟腱反射减弱。双足皮肤感觉减退，双下肢髂腰肌肌力左侧Ⅳ级，右侧Ⅳ级；双侧股四头肌肌力左侧Ⅳ级，右侧Ⅳ级。胫骨前肌肌力左侧Ⅳ级，右侧Ⅳ级；腓肠肌肌力左侧Ⅳ级，右侧Ⅳ级；拇背伸肌肌力左侧Ⅳ级，右侧Ⅳ级。右足背动脉可扪及。病理征未引出。\n')
# Out:
# True

# %%
youtuitaigaoyin('下肢直腿抬高试验阴性')

# %%
#5）左侧下肢感觉异常
def zuoxiazhiyichang(text):
    rule = r'(左侧腿|双下肢|双足皮肤|左下肢|左大腿|左腿|左足)[^.,，。：；]*感觉[^.,，。：；]*(异常|减退)'
    match = re.search(rule, text, re.I)
    match_result = Match_true_false(match)
    return match_result

# %%
zuoxiazhiyichang('体温：36.8℃；\n脉搏：80次/分钟；\n呼吸频率：20次/分钟；\n收缩压：119mmHg；\n舒张压：81mmHg；\n一般情况：发育正常，营养状况良好，神志清，对答切题，查体配合\n皮肤黏膜：无色素沉着、皮肤光滑及弹性尚可，无皮疹，无出血、无皮下结节。\n淋巴结：全身浅表淋巴节无肿大，触之无压痛。\n头部及其器官：头颅  形态对称，无包块、无压痛   头皮 头发浓密有光泽  \n眼睛  眼睑无水肿，双侧视力可   巩膜  无黄染   瞳孔  等大等圆，对光反射存在\n耳  听力可，无流脓及乳突压痛   鼻  通畅   口咽  无充血、红肿。\n颈部：颈软且无抵抗，双侧对称。甲状腺无肿大，气管居中\n胸部：胸廓对称，腹式呼吸为主，节律规整。\n心脏：心脏  心率80次/分，律齐，各听诊区未闻及明显病理性杂音,无心包摩擦音。\n肺脏：肺部  两肺呼吸音正常，未闻及干、湿啰音。\n血管：无色素沉着、皮肤光滑及弹性尚可，无皮疹，无出血、无皮下结节。\n腹部：腹对称，腹壁静脉无怒张无隆起，腹壁柔软,无压痛、反跳痛、振水音及液波震颤，肝脾肋下未及，移动性浊音（-），肠鸣音正常，无血管杂音。\n肛门直肠,外生殖器：未查\n脊柱四肢：见专科检查\n神经系统：腹壁反射等生理反射正常，Babinski征等病理反射未引出。\n专科检查：脊柱生理弯曲存在，腰椎棘突旁无明显压痛，无明显叩击痛。左下肢直腿抬高试验阳性，加强试验阳性。右下肢直腿抬高试验阴性，加强试验阴性。双膝反射正常，双下肢跟腱反射正常。左下肢远端感觉减退，右下肢感觉正常，双下肢髂腰肌肌力左侧Ⅳ级，右侧Ⅴ级；双侧股四头肌肌力左侧Ⅳ级，右侧Ⅴ级。胫骨前肌肌力左侧Ⅳ级，右侧Ⅴ级；拇背伸肌肌力左侧Ⅳ级，右侧Ⅴ级。腓肠肌肌力左侧Ⅳ级，右侧Ⅴ级。双下肢足背动脉可扪及。病理征未引出。\n')
# Out:
# True

# %%
zuoxiazhiyichang('左侧腿的感觉不是很对异常')
# Out:
# True

# %%
#6）右侧下肢感觉异常
def youxiazhiyichang(text):
    rule = r'(右侧腿|双下肢|双足皮肤|右下肢|右大腿|右腿|右足)[^.,，。：；]*感觉[^.,，。：；]*(异常|减退)'
    match = re.search(rule, text, re.I)
    match_result = Match_true_false(match)
    return match_result

# %%
youxiazhiyichang('右侧腿的感觉不是很对异常')
# Out:
# True

# %%
#7）左侧下肢感觉正常
def zuoxiazhizhengchang(text):
    rule = r'(左侧腿|双下肢|左下肢|左大腿|左腿|左足)[^.,，。：；]*感觉[^.,，。：；]*正常'
    match = re.search(rule, text, re.I)
    match_result = Match_true_false(match)
    return match_result

# %%
aa1 = '体温：36.8℃；\n脉搏：80次/分钟；\n呼吸频率：20次/分钟；\n收缩压：119mmHg；\n舒张压：81mmHg；\n一般情况：发育正常，营养状况良好，神志清，对答切题，查体配合\n皮肤黏膜：无色素沉着、皮肤光滑及弹性尚可，无皮疹，无出血、无皮下结节。\n淋巴结：全身浅表淋巴节无肿大，触之无压痛。\n头部及其器官：头颅  形态对称，无包块、无压痛   头皮 头发浓密有光泽  \n眼睛  眼睑无水肿，双侧视力可   巩膜  无黄染   瞳孔  等大等圆，对光反射存在\n耳  听力可，无流脓及乳突压痛   鼻  通畅   口咽  无充血、红肿。\n颈部：颈软且无抵抗，双侧对称。甲状腺无肿大，气管居中\n胸部：胸廓对称，腹式呼吸为主，节律规整。\n心脏：心脏  心率80次/分，律齐，各听诊区未闻及明显病理性杂音,无心包摩擦音。\n肺脏：肺部  两肺呼吸音正常，未闻及干、湿啰音。\n血管：无色素沉着、皮肤光滑及弹性尚可，无皮疹，无出血、无皮下结节。\n腹部：腹对称，腹壁静脉无怒张无隆起，腹壁柔软,无压痛、反跳痛、振水音及液波震颤，肝脾肋下未及，移动性浊音（-），肠鸣音正常，无血管杂音。\n肛门直肠,外生殖器：未查\n脊柱四肢：见专科检查\n神经系统：腹壁反射等生理反射正常，Babinski征等病理反射未引出。\n专科检查：脊柱生理弯曲存在，腰椎棘突旁无明显压痛，无明显叩击痛。左下肢直腿抬高试验阳性，加强试验阳性。右下肢直腿抬高试验阴性，加强试验阴性。双膝反射正常，双下肢跟腱反射正常。左下肢远端感觉减退，右下肢感觉正常，双下肢髂腰肌肌力左侧Ⅳ级，右侧Ⅴ级；双侧股四头肌肌力左侧Ⅳ级，右侧Ⅴ级。胫骨前肌肌力左侧Ⅳ级，右侧Ⅴ级；拇背伸肌肌力左侧Ⅳ级，右侧Ⅴ级。腓肠肌肌力左侧Ⅳ级，右侧Ⅴ级。双下肢足背动脉可扪及。病理征未引出。\n'

# %%
match = re.search(r'(左侧腿|双下肢|左下肢|左大腿|左腿|左足)[^.,，。：；]*感觉[^.,，。：；]*正常', aa1, re.I)
print(match)
# Out:
# None

# %%
zuoxiazhizhengchang('体温：36.8℃；\n脉搏：80次/分钟；\n呼吸频率：20次/分钟；\n收缩压：119mmHg；\n舒张压：81mmHg；\n一般情况：发育正常，营养状况良好，神志清，对答切题，查体配合\n皮肤黏膜：无色素沉着、皮肤光滑及弹性尚可，无皮疹，无出血、无皮下结节。\n淋巴结：全身浅表淋巴节无肿大，触之无压痛。\n头部及其器官：头颅  形态对称，无包块、无压痛   头皮 头发浓密有光泽  \n眼睛  眼睑无水肿，双侧视力可   巩膜  无黄染   瞳孔  等大等圆，对光反射存在\n耳  听力可，无流脓及乳突压痛   鼻  通畅   口咽  无充血、红肿。\n颈部：颈软且无抵抗，双侧对称。甲状腺无肿大，气管居中\n胸部：胸廓对称，腹式呼吸为主，节律规整。\n心脏：心脏  心率80次/分，律齐，各听诊区未闻及明显病理性杂音,无心包摩擦音。\n肺脏：肺部  两肺呼吸音正常，未闻及干、湿啰音。\n血管：无色素沉着、皮肤光滑及弹性尚可，无皮疹，无出血、无皮下结节。\n腹部：腹对称，腹壁静脉无怒张无隆起，腹壁柔软,无压痛、反跳痛、振水音及液波震颤，肝脾肋下未及，移动性浊音（-），肠鸣音正常，无血管杂音。\n肛门直肠,外生殖器：未查\n脊柱四肢：见专科检查\n神经系统：腹壁反射等生理反射正常，Babinski征等病理反射未引出。\n专科检查：脊柱生理弯曲存在，腰椎棘突旁无明显压痛，无明显叩击痛。左下肢直腿抬高试验阳性，加强试验阳性。右下肢直腿抬高试验阴性，加强试验阴性。双膝反射正常，双下肢跟腱反射正常。左下肢远端感觉减退，右下肢感觉正常，双下肢髂腰肌肌力左侧Ⅳ级，右侧Ⅴ级；双侧股四头肌肌力左侧Ⅳ级，右侧Ⅴ级。胫骨前肌肌力左侧Ⅳ级，右侧Ⅴ级；拇背伸肌肌力左侧Ⅳ级，右侧Ⅴ级。腓肠肌肌力左侧Ⅳ级，右侧Ⅴ级。双下肢足背动脉可扪及。病理征未引出。\n')

# %%
rule = r'(左侧腿|双下肢|左下肢|左大腿|左腿|左足)[^.,，。：；]*感觉[^.,，。：；]*正常'
match = re.search(rule, aa1, re.I)
print(match)
# Out:
# None

# %%
match_result = Match_true_false(match)
print(match_result)
# Out:
# None

# %%
zuoxiazhizhengchang(aa1)

# %%
zuoxiazhizhengchang('体温：36.8℃；\n脉搏：80次/分钟；\n呼吸频率：20次/分钟；\n收缩压：119mmHg；\n舒张压：81mmHg；\n一般情况：发育正常，营养状况良好，神志清，对答切题，查体配合\n皮肤黏膜：无色素沉着、皮肤光滑及弹性尚可，无皮疹，无出血、无皮下结节。\n淋巴结：全身浅表淋巴节无肿大，触之无压痛。\n头部及其器官：头颅  形态对称，无包块、无压痛   头皮 头发浓密有光泽  \n眼睛  眼睑无水肿，双侧视力可   巩膜  无黄染   瞳孔  等大等圆，对光反射存在\n耳  听力可，无流脓及乳突压痛   鼻  通畅   口咽  无充血、红肿。\n颈部：颈软且无抵抗，双侧对称。甲状腺无肿大，气管居中\n胸部：胸廓对称，腹式呼吸为主，节律规整。\n心脏：心脏  心率80次/分，律齐，各听诊区未闻及明显病理性杂音,无心包摩擦音。\n肺脏：肺部  两肺呼吸音正常，未闻及干、湿啰音。\n血管：无色素沉着、皮肤光滑及弹性尚可，无皮疹，无出血、无皮下结节。\n腹部：腹对称，腹壁静脉无怒张无隆起，腹壁柔软,无压痛、反跳痛、振水音及液波震颤，肝脾肋下未及，移动性浊音（-），肠鸣音正常，无血管杂音。\n肛门直肠,外生殖器：未查\n脊柱四肢：见专科检查\n神经系统：腹壁反射等生理反射正常，Babinski征等病理反射未引出。\n专科检查：脊柱生理弯曲存在，腰椎棘突旁无明显压痛，无明显叩击痛。左下肢直腿抬高试验阳性，加强试验阳性。右下肢直腿抬高试验阴性，加强试验阴性。双膝反射正常，双下肢跟腱反射正常。左下肢远端感觉减退，右下肢感觉正常，双下肢髂腰肌肌力左侧Ⅳ级，右侧Ⅴ级；双侧股四头肌肌力左侧Ⅳ级，右侧Ⅴ级。胫骨前肌肌力左侧Ⅳ级，右侧Ⅴ级；拇背伸肌肌力左侧Ⅳ级，右侧Ⅴ级。腓肠肌肌力左侧Ⅳ级，右侧Ⅴ级。双下肢足背动脉可扪及。病理征未引出。\n')

# %%
zuoxiazhizhengchang('体温：36.5℃；\n脉搏：72次/分钟；\n呼吸频率：18次/分钟；\n收缩压：137mmHg；\n舒张压：67mmHg；\n一般情况：发育正常，营养状况良好，神志清，对答切题，查体配合\n皮肤黏膜：无色素沉着、皮肤光滑及弹性尚可，无皮疹，无出血、无皮下结节。\n淋巴结：全身浅表淋巴节无肿大，触之无压痛。\n头部及其器官：头颅  形态对称，无包块、无压痛   头皮 头发浓密有光泽  \n眼睛  眼睑无水肿，双侧视力可   巩膜  无黄染   瞳孔  等大等圆，对光反射存在\n耳  听力可，无流脓及乳突压痛   鼻  通畅   口咽  无充血、红肿。\n颈部：颈软且无抵抗，双侧对称。甲状腺无肿大，气管居中\n胸部：胸廓对称，腹式呼吸为主，节律规整。\n心脏：心脏  心率80次/分，律齐，各听诊区未闻及明显病理性杂音,无心包摩擦音。\n肺脏：肺部  两肺呼吸音正常，未闻及干、湿啰音。\n血管：无色素沉着、皮肤光滑及弹性尚可，无皮疹，无出血、无皮下结节。\n腹部：腹对称，腹壁静脉无怒张无隆起，腹壁柔软,无压痛、反跳痛、振水音及液波震颤，肝脾肋下未及，移动性浊音（-），肠鸣音正常，无血管杂音。\n肛门直肠,外生殖器：未查\n脊柱四肢：见专科检查\n神经系统：腹壁反射、膝腱及跟腱反射等生理反射正常，Babinski征等病理反射未引出。\n专科检查：强迫体位步入病房，脊柱生理弯曲存在，腰椎棘突旁无明显压痛，无明显叩击痛，双下肢直腿抬高试验右下肢阳性，只能抬高至60°，右下肢加强试验阳性，双膝反射亢进，双下肢跟腱反射正常。双下肢感觉对称正常，双下肢髂腰肌肌力左侧Ⅴ级，右侧Ⅴ级；双侧股四头肌肌力左侧Ⅴ级，右侧Ⅴ级。胫骨前肌肌力左侧Ⅴ级，右侧IⅤ级；拇背伸肌肌力左侧Ⅴ级，右侧Ⅴ级。腓肠肌肌力左侧Ⅴ级，右侧IⅤ级。右足背动脉可扪及。病理征未引出。\n')
# Out:
# True

# %%
zuoxiazhizhengchang('右侧腿的感觉不是很对正常')

# %%
#8）右侧下肢感觉正常
def youxiazhizhengchang(text):
    rule = r'(右侧腿|双下肢|右下肢|右大腿|右腿)[^.,，。：；]*感觉[^.,，。：；]*正常'
    match = re.search(rule, text, re.I)
    match_result = Match_true_false(match)
    return match_result

# %%
#9) 左侧膝腱反射正常
def zuoxijianzhengchang(text):
    rule = r'(双膝|双侧膝|左下肢|腿|膝腱)[^.,，。：；]*(反射|膝反射)[^.,，。：；]*正常'
#     rule = r'(双膝|双侧膝|左下肢|腿)[^.,，。：；]*(反射|膝反射)[^.,，。：；]*正常'
    match = re.search(rule, text, re.I)
    match_result = Match_true_false(match)
    return match_result

# %%
a3 = '显压痛，无明显叩击痛。双下肢直腿抬高试验阳性（左侧30°，右侧50°），加强试验阳性。双膝反射减弱，双下肢跟腱反射正常。双下肢感觉对称正常'

# %%
rule = r'(双膝|双侧膝|左下肢|腿)[^.,，。：；]*(反射|膝反射)[^.,，。：；]*正常'
match = re.search(rule, a3, re.I)
print(match)
# Out:
# None

# %%
#10) 左侧膝腱反射减弱
def zuoxijianjianruo(text):
    rule = r'(双膝|双侧膝|左下肢|腿)[^.,，。：；]*(反射|膝反射)[^.,，。：；]*(减弱|弱|\+)'
    match = re.search(rule, text, re.I)
    match_result = Match_true_false(match)
    return match_result

# %%
zuoxijianjianruo('，腰椎棘突旁压痛、叩击痛阴性，双下肢直腿抬高试验及加强试验阴性。双膝反射、跟腱反射减弱。')
# Out:
# True

# %%
#11) 左侧膝腱反射消失
def zuoxijianxiaoshi(text):
    rule = r'(双膝|双侧膝|左下肢|腿)[^.,，。：；]*(反射|膝反射)[^.,，。：；]*(消失|未引出|失|阴性|\-)'
    match = re.search(rule, text, re.I)
    match_result = Match_true_false(match)
    return match_result

# %%
zuoxijianxiaoshi('双膝反射消失，双下肢跟腱反射减弱。双下肢感')
# Out:
# True

# %%
#12) 左侧跟腱反射正常
def zuogenjianzhengchang(text):
    rule = r'(双下肢|左下肢|腿|双侧|)[^.,，。：；]*(跟腱反射|腱反射)[^.,，。：；]*正常'
    match = re.search(rule, text, re.I)
    match_result = Match_true_false(match)
    return match_result

# %%
zuogenjianzhengchang('双膝反射减弱，双下肢跟腱反射正常。双下肢感')
# Out:
# True

# %%
#13) 左侧跟腱反射减弱
def zuogenjianjianruo(text):
    rule = r'(双下肢|左下肢|腿|、)[^.,，。：；]*(跟腱反射|腱反射)[^.,，。：；]*(减弱|弱|\+)'
    match = re.search(rule, text, re.I)
    match_result = Match_true_false(match)
    return match_result

# %%
zuogenjianjianruo('体温：36.8℃；\n脉搏：80次/分钟；\n呼吸频率：20次/分钟；\n收缩压：128mmHg；\n舒张压：70mmHg；\n一般情况：发育正常，营养状况良好，神志清，对答切题，查体配合\n皮肤黏膜：无色素沉着、皮肤光滑及弹性尚可，无皮疹，无出血、无皮下结节。\n淋巴结：全身浅表淋巴节无肿大，触之无压痛。\n头部及其器官：头颅  形态对称，无包块、无压痛   头皮 头发浓密有光泽  \n眼睛  眼睑无水肿，双侧视力可   巩膜  无黄染   瞳孔  等大等圆，对光反射存在\n耳  听力可，无流脓及乳突压痛   鼻  通畅   口咽  无充血、红肿。\n颈部：颈软且无抵抗，双侧对称。甲状腺无肿大，气管居中\n胸部：胸廓对称，腹式呼吸为主，节律规整。\n心脏：心脏  心率78次/分，律齐，各听诊区未闻及明显病理性杂音,无心包摩擦音。\n肺脏：肺部  两肺呼吸音正常，未闻及干、湿啰音。\n血管：无色素沉着、皮肤光滑及弹性尚可，无皮疹，无出血、无皮下结节。\n腹部：腹对称，腹壁静脉无怒张无隆起，腹壁柔软,无压痛、反跳痛、振水音及液波震颤，肝脾肋下未及，移动性浊音（-），肠鸣音正常，无血管杂音。\n肛门直肠,外生殖器：未查\n脊柱四肢：见专科检查\n神经系统：见专科检查\n专科检查：脊柱生理弯曲存在，腰椎棘突旁压痛、叩击痛（-），右下肢直腿抬高试验阳性，加强试验阳性，左下肢正常，双膝反射、跟腱反射减弱。双下肢感觉对称正常，双下肢髂腰肌肌力左侧Ⅴ级，右侧Ⅴ级；双侧股四头肌肌力左侧Ⅴ级，右侧Ⅴ级。胫骨前肌肌力左侧Ⅴ级，右侧Ⅴ级；拇背伸肌肌力左侧Ⅴ级，右侧Ⅴ级。腓肠肌肌力左侧Ⅴ级，右侧Ⅴ级。右足背动脉可扪及。病理征未引出。\n')
# Out:
# True

# %%
zuogenjianjianruo('双膝反射dd，双下肢跟腱反射+。双下肢感')
# Out:
# True

# %%
#14) 左侧跟腱反射消失
def zuogenjianxiaoshi(text):
    rule = r'(双下肢|左下肢|腿)[^.,，。：；]*(跟腱反射|腱反射)[^.,，。：；]*(消失|未引出|失|阴性|\-)'
    match = re.search(rule, text, re.I)
    match_result = Match_true_false(match)
    return match_result

# %%
zuogenjianxiaoshi('双膝反射dd，双下肢跟腱反射消失。双下肢感')
# Out:
# True

# %%
#15) 右侧侧膝腱反射正常
def youxijianzhengchang(text):
    rule = r'(双膝|双侧膝|右侧下肢|双侧)[^.,，。：；]*(反射|膝反射)[^.,，。：；]*正常'
    match = re.search(rule, text, re.I)
    match_result = Match_true_false(match)
    return match_result

# %%
youxijianzhengchang('柱生理弯曲存在，腰椎棘突旁压痛、叩击痛阴性，双下肢直腿抬高试验及加强试验阴性。双膝反射、跟腱反射正常。')
# Out:
# True

# %%
#15.5) 右侧侧膝腱反射减弱
def youxijianjianruo(text):
    rule = r'(双膝|双侧膝|右侧下肢|右膝)[^.,，。：；]*(反射|膝反射)[^.,，。：；]*(减弱|弱|\+)'
    match = re.search(rule, text, re.I)
    match_result = Match_true_false(match)
    return match_result

# %%
youxijianjianruo('双膝反射、跟腱反射减弱。')
# Out:
# True

# %%
#16) 右侧侧膝腱反射消失
def youxijianxiaoshi(text):
    rule = r'(双膝|双侧膝|右侧下肢|右膝)[^.,，。：；]*(反射|膝反射)[^.,，。：；]*(消失|未引出|失|阴性|\-)'
    match = re.search(rule, text, re.I)
    match_result = Match_true_false(match)
    return match_result

# %%
#17) 右侧跟腱反射正常 ->  
def yougenjianzhengchang(text):
    rule = r'(双下肢|右下肢|腿|)[^.,，。：；]*(跟腱反射|腱反射)[^.,，。：；]*正常'
    match = re.search(rule, text, re.I)
    match_result = Match_true_false(match)
    return match_result

# %%
zuogenjianzhengchang('双膝反射减弱，跟腱反射正常。双下肢感')
# Out:
# True

# %%
#18) 右侧跟腱反射减弱  
def yougenjianjianruo(text):
    rule = r'(双下肢|右下肢|腿|)[^.,，。：；]*(跟腱反射|腱反射)[^.,，。：；]*(减弱|弱|\+)'
    match = re.search(rule, text, re.I)
    match_result = Match_true_false(match)
    return match_result

# %%
#19) 右侧跟腱反射消失  
def yougenjianxiaoshi(text):
    rule = r'(双下肢|右下肢|腿|)[^.,，。：；]*(跟腱反射|腱反射)[^.,，。：；]*(消失|未引出|失|阴性|\-)'
    match = re.search(rule, text, re.I)
    match_result = Match_true_false(match)
    return match_result

# %%
#20) 左侧跟腱反射亢进
def zuogenjiankangjin(text):
    rule = r'(双下肢|左下肢|腿)[^.,，。：；]*(跟腱反射|腱反射)[^.,，。：；]*(亢进|\+\+\+)'
    match = re.search(rule, text, re.I)
    match_result = Match_true_false(match)
    return match_result

# %%
#21) 右侧跟腱反射亢进
def yougenjiankangjin(text):
    rule = r'(双下肢|右下肢|腿)[^.,，。：；]*(跟腱反射|腱反射)[^.,，。：；]*(亢进|\+\+\+)'
    match = re.search(rule, text, re.I)
    match_result = Match_true_false(match)
    return match_result

# %%
#22) 左侧膝腱反射亢进
def zuoxijiankangjin(text):
    rule = r'(双膝|双侧膝|左下肢|腿)[^.,，。：；]*(反射|膝反射)[^.,，。：；]*(亢进|\+\+\+)'
    match = re.search(rule, text, re.I)
    match_result = Match_true_false(match)
    return match_result

# %%
#23) 右侧膝腱反射亢进
def youxijiankangjin(text):
    rule = r'(双膝|双侧膝|右下肢|腿)[^.,，。：；]*(反射|膝反射)[^.,，。：；]*(亢进|\+\+\+)'
    match = re.search(rule, text, re.I)
    match_result = Match_true_false(match)
    return match_result

# %%
import os

# %%
os.chdir('/Users/a1/Desktop/Final_test/')

# %%
train_df_tgjc1 = pd.read_csv('体格检查.csv')
train_df_tgjc1.head()
# Out:
#    patient_id  record_id     inpat_id patient_name  record_type_code  \
# 0     3761447    2033812  101138091.0          邓小龙              2624
# 1       48780     405344  101037471.0          许海玉              2624
# 2      263726     925793  101044615.0           唐强              2624
# 3     2704599     865029  101039659.0          沈险峰              2624
# 4     1438474    1224968  101093496.0           龚晔              2624
#
#   report_type       report_time  \
# 0          pe  2018-08-27 13:27
# 1          pe  2018-08-27 13:27
# 2          pe  2018-08-27 13:27
# 3          pe  2018-08-27 13:27
# 4          pe  2018-08-27 13:27
#
# ...

# %%
# train_df_tgjc1.describe

# %%
train_df_tgjc1['左侧直腿抬高阳性'] = train_df_tgjc1['tgjc'].map(lambda x: zuotuitaigaoyang(x)) #1)

train_df_tgjc1['右侧直腿抬高阳性'] = train_df_tgjc1['tgjc'].map(lambda x: youtuitaigaoyang(x)) #2）

train_df_tgjc1['左侧直腿抬高阴性'] = train_df_tgjc1['tgjc'].map(lambda x: zuotuitaigaoyin(x)) #3）

train_df_tgjc1['右侧直腿抬高阴性'] = train_df_tgjc1['tgjc'].map(lambda x: youtuitaigaoyin(x)) #4）

train_df_tgjc1['左侧下肢感觉异常'] = train_df_tgjc1['tgjc'].map(lambda x: zuoxiazhiyichang(x)) #5）

train_df_tgjc1['右侧下肢感觉异常'] = train_df_tgjc1['tgjc'].map(lambda x: youxiazhiyichang(x)) #6）

train_df_tgjc1['左侧下肢感觉正常'] = train_df_tgjc1['tgjc'].map(lambda x: zuoxiazhizhengchang(x)) #7）

train_df_tgjc1['右侧下肢感觉正常'] = train_df_tgjc1['tgjc'].map(lambda x: youxiazhizhengchang(x)) #8）

train_df_tgjc1['左侧膝腱反射正常'] = train_df_tgjc1['tgjc'].map(lambda x: zuoxijianzhengchang(x)) #9）

train_df_tgjc1['左侧膝腱反射减弱'] = train_df_tgjc1['tgjc'].map(lambda x: zuoxijianjianruo(x)) #10）

train_df_tgjc1['左侧膝腱反射消失'] = train_df_tgjc1['tgjc'].map(lambda x: zuoxijianxiaoshi(x)) #11）

train_df_tgjc1['左侧跟腱反射正常'] = train_df_tgjc1['tgjc'].map(lambda x: zuogenjianzhengchang(x)) #12）

train_df_tgjc1['左侧跟腱反射减弱'] = train_df_tgjc1['tgjc'].map(lambda x: zuogenjianjianruo(x)) #13）

train_df_tgjc1['左侧跟腱反射消失'] = train_df_tgjc1['tgjc'].map(lambda x: zuogenjianxiaoshi(x)) #14）

train_df_tgjc1['右侧侧膝腱反射正常'] = train_df_tgjc1['tgjc'].map(lambda x: youxijianzhengchang(x)) #15）

train_df_tgjc1['右侧侧膝腱反射减弱'] = train_df_tgjc1['tgjc'].map(lambda x: youxijianjianruo(x)) #15.5）

train_df_tgjc1['右侧侧膝腱反射消失'] = train_df_tgjc1['tgjc'].map(lambda x: youxijianxiaoshi(x)) #16）

train_df_tgjc1['右侧跟腱反射正常'] = train_df_tgjc1['tgjc'].map(lambda x: yougenjianzhengchang(x)) #17）

train_df_tgjc1['右侧跟腱反射减弱'] = train_df_tgjc1['tgjc'].map(lambda x: yougenjianjianruo(x)) #18）

train_df_tgjc1['右侧跟腱反射消失'] = train_df_tgjc1['tgjc'].map(lambda x: yougenjianxiaoshi(x)) #19）

train_df_tgjc1['左侧跟腱反射亢进'] = train_df_tgjc1['tgjc'].map(lambda x: zuogenjiankangjin(x)) #20）

train_df_tgjc1['右侧跟腱反射亢进'] = train_df_tgjc1['tgjc'].map(lambda x: yougenjiankangjin(x)) #21）

train_df_tgjc1['左侧膝腱反射亢进'] = train_df_tgjc1['tgjc'].map(lambda x: zuoxijiankangjin(x)) #22）

train_df_tgjc1['右侧膝腱反射亢进'] = train_df_tgjc1['tgjc'].map(lambda x: youxijiankangjin(x)) #23）

# %%
writer = pd.ExcelWriter('/Users/a1/Desktop/Final_test/tigejiancha_8.29.xlsx')
train_df_tgjc1.to_excel(writer, 'tigejiancha')
writer.save()

# %%
pd.set_option('display.max_columns', None) #显示出所有的列

# %%
train_df_tgjc1.head()
# Out:
#    patient_id  record_id     inpat_id patient_name  record_type_code  \
# 0     3761447    2033812  101138091.0          邓小龙              2624
# 1       48780     405344  101037471.0          许海玉              2624
# 2      263726     925793  101044615.0           唐强              2624
# 3     2704599     865029  101039659.0          沈险峰              2624
# 4     1438474    1224968  101093496.0           龚晔              2624
#
#   report_type       report_time  \
# 0          pe  2018-08-27 13:27
# 1          pe  2018-08-27 13:27
# 2          pe  2018-08-27 13:27
# 3          pe  2018-08-27 13:27
# 4          pe  2018-08-27 13:27
#
# ...
